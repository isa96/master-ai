# %%
import numpy as np
import pandas as pd

# %%
DATA_PATH = 'romania_cities.xlsx'

def load_matrix(path=None):
    path = path or DATA_PATH
    adj_matrix = pd.read_excel(path, sheet_name='matrix')
    adj_matrix = adj_matrix.set_index('source')
    np.fill_diagonal(adj_matrix.values, 0)
    return adj_matrix

def load_heuristic(path=None):
    path = path or DATA_PATH
    heuristic = pd.read_excel(path, sheet_name='heuristic')
    heuristic = heuristic.set_index('source').line_distance
    return heuristic

# %%
adj_matrix = load_matrix()
adj_matrix
# Out:
#             arad  bucharest  craiova  dobreta  eforie  fagaras  giurgiu  \
# source
# arad         0.0        NaN      NaN      NaN     NaN      NaN      NaN
# bucharest    NaN        0.0      NaN      NaN     NaN      NaN     90.0
# craiova      NaN        NaN      0.0    120.0     NaN      NaN      NaN
# dobreta      NaN        NaN    120.0      0.0     NaN      NaN      NaN
# eforie       NaN        NaN      NaN      NaN     0.0      NaN      NaN
# fagaras      NaN      211.0      NaN      NaN     NaN      0.0      NaN
# giurgiu      NaN       90.0      NaN      NaN     NaN      NaN      0.0
# hirsova      NaN        NaN      NaN      NaN    86.0      NaN      NaN
# iasi         NaN        NaN      NaN      NaN     NaN      NaN      NaN
# lugoj        NaN        NaN      NaN      NaN     NaN      NaN      NaN
# mehadia      NaN        NaN      NaN     75.0     NaN      NaN      NaN
# neamt        NaN        NaN      NaN      NaN     NaN      NaN      NaN
# oradea       NaN        NaN      NaN      NaN     NaN      NaN      NaN
# pitesti      NaN      101.0    138.0      NaN     NaN      NaN      NaN
# rimnicu      NaN        NaN    146.0      NaN     NaN      NaN      NaN
# sibiu      140.0        NaN      NaN      NaN     NaN     99.0      NaN
# timisoara  118.0        NaN      NaN      NaN     NaN      NaN      NaN
# urziceni     NaN       85.0      NaN      NaN     NaN      NaN      NaN
# vaslui       NaN        NaN      NaN      NaN     NaN      NaN      NaN
# zerind      75.0        NaN      NaN      NaN     NaN      NaN      NaN
#
#            hirsova  iasi  lugoj  mehadia  neamt  oradea  pitesti  rimnicu  \
# source
# arad           NaN   NaN    NaN      NaN    NaN     NaN      NaN      NaN
# bucharest      NaN   NaN    NaN      NaN    NaN     NaN    101.0      NaN
# craiova        NaN   NaN    NaN      NaN    NaN     NaN    138.0    146.0
# dobreta        NaN   NaN    NaN     75.0    NaN     NaN      NaN      NaN
# eforie        86.0   NaN    NaN      NaN    NaN     NaN      NaN      NaN
# fagaras        NaN   NaN    NaN      NaN    NaN     NaN      NaN      NaN
# giurgiu        NaN   NaN    NaN      NaN    NaN     NaN      NaN      NaN
# hirsova        0.0   NaN    NaN      NaN    NaN     NaN      NaN      NaN
# iasi           NaN   0.0    NaN      NaN   87.0     NaN      NaN      NaN
# lugoj          NaN   NaN    0.0     70.0    NaN     NaN      NaN      NaN
# mehadia        NaN   NaN   70.0      0.0    NaN     NaN      NaN      NaN
# neamt          NaN  87.0    NaN      NaN    0.0     NaN      NaN      NaN
# oradea         NaN   NaN    NaN      NaN    NaN     0.0      NaN      NaN
# pitesti        NaN   NaN    NaN      NaN    NaN     NaN      0.0     97.0
# rimnicu        NaN   NaN    NaN      NaN    NaN     NaN     97.0      0.0
# sibiu          NaN   NaN    NaN      NaN    NaN   151.0      NaN     80.0
# timisoara      NaN   NaN  111.0      NaN    NaN     NaN      NaN      NaN
# urziceni      98.0   NaN    NaN      NaN    NaN     NaN      NaN      NaN
# vaslui         NaN  92.0    NaN      NaN    NaN     NaN      NaN      NaN
# zerind         NaN   NaN    NaN      NaN    NaN    71.0      NaN      NaN
#
#            sibiu  timisoara  urziceni  vaslui  zerind
# source
# arad       140.0      118.0       NaN     NaN    75.0
# bucharest    NaN        NaN      85.0     NaN     NaN
# craiova      NaN        NaN       NaN     NaN     NaN
# dobreta      NaN        NaN       NaN     NaN     NaN
# eforie       NaN        NaN       NaN     NaN     NaN
# fagaras     99.0        NaN       NaN     NaN     NaN
# giurgiu      NaN        NaN       NaN     NaN     NaN
# hirsova      NaN        NaN      98.0     NaN     NaN
# iasi         NaN        NaN       NaN    92.0     NaN
# lugoj        NaN      111.0       NaN     NaN     NaN
# mehadia      NaN        NaN       NaN     NaN     NaN
# neamt        NaN        NaN       NaN     NaN     NaN
# oradea     151.0        NaN       NaN     NaN    71.0
# pitesti      NaN        NaN       NaN     NaN     NaN
# rimnicu     80.0        NaN       NaN     NaN     NaN
# sibiu        0.0        NaN       NaN     NaN     NaN
# timisoara    NaN        0.0       NaN     NaN     NaN
# urziceni     NaN        NaN       0.0   142.0     NaN
# vaslui       NaN        NaN     142.0     0.0     NaN
# zerind       NaN        NaN       NaN     NaN     0.0

# %%
heuristic = load_heuristic()
heuristic
# Out:
# source
# arad         366
# bucharest      0
# craiova      160
# dobreta      242
# eforie       161
# fagaras      178
# giurgiu       77
# hirsova      151
# iasi         226
# lugoj        244
# mehadia      241
# neamt        234
# oradea       380
# pitesti       98
# rimnicu      193
# sibiu        253
# timisoara    329
# urziceni      80
# vaslui       199
# zerind       374
# Name: line_distance, dtype: int64

# %%
def neighbor(src, adj_matrix):
    idx = np.where(adj_matrix.loc[src].notnull())
    res = adj_matrix.columns[idx]
    res = res[res != src].tolist()
    return res

print(neighbor('arad', adj_matrix))
print(neighbor('bucharest', adj_matrix))
# Out:
# ['sibiu', 'timisoara', 'zerind']
# ['giurgiu', 'pitesti', 'urziceni']

# %%
def a_star(src, dst, adj_matrix, heuristic):
    closed = set()
    opened = pd.Series(np.nan, index=heuristic.index, name='opened')
    parent = pd.Series(np.nan, index=heuristic.index, name='parent')
    f = pd.Series(np.nan, index=heuristic.index, name='f')
    g = pd.Series(np.nan, index=heuristic.index, name='g')

    parent[src] = src
    opened[src] = heuristic[src]
    f[src] = heuristic[src]
    g[src] = 0
    found = False

    # while opened is not empty
    while not opened.isnull().all():
        q = opened.idxmin()
        opened[q] = np.nan # remove q from opened

        neighbors = neighbor(q, adj_matrix)
        for v in neighbors:
            if v == dst:
                found = True
                break

            if v in closed:
                continue

            new_g = g[q] + adj_matrix.loc[v, q]
            new_f = new_g + heuristic[v]

            if np.isnan(opened[v]) or new_f < opened[v]:
                # if v not in opened or in opened but with higher f than the new f
                print(f'Updated {q} -> {v}, new_f: {new_f}, new_g: {new_g}')
                g[v] = new_g
                f[v] = new_f
                opened[v] = new_f
                parent[v] = q
            
        closed.add(q)

    return f, g, parent

# %%
src = 'timisoara'
dst = 'bucharest'

f, g, parent = a_star(src=src, dst=dst, adj_matrix=adj_matrix, heuristic=heuristic)
# Out:
# Updated timisoara -> arad, new_f: 484.0, new_g: 118.0
# Updated timisoara -> lugoj, new_f: 355.0, new_g: 111.0
# Updated lugoj -> mehadia, new_f: 422.0, new_g: 181.0
# Updated mehadia -> dobreta, new_f: 498.0, new_g: 256.0
# Updated arad -> sibiu, new_f: 511.0, new_g: 258.0
# Updated arad -> zerind, new_f: 567.0, new_g: 193.0
# Updated dobreta -> craiova, new_f: 536.0, new_g: 376.0
# Updated sibiu -> fagaras, new_f: 535.0, new_g: 357.0
# Updated sibiu -> oradea, new_f: 789.0, new_g: 409.0
# Updated sibiu -> rimnicu, new_f: 531.0, new_g: 338.0
# Updated rimnicu -> pitesti, new_f: 533.0, new_g: 435.0
# Updated zerind -> oradea, new_f: 644.0, new_g: 264.0

# %%
cur = 'fagaras'
dist = 0
while cur != src:
    print(cur, end=' -> ')
    dist += adj_matrix.loc[cur, parent[cur]]
    cur = parent[cur]
print(cur, dist)
# Out:
# fagaras -> sibiu -> arad -> timisoara 357.0
